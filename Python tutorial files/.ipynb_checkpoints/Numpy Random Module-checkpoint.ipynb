# %% [markdown]
# - rand: Random values in a given shape
# - randn: Return a sample(or samples) from the "standard normal" distribution
# - randint: Return random integers from low (inclusive) to high (exclusive)
# - random: Return random floats in the half-open interval[0.0,1.0)
# - choice: Generates a random sample from a given 1-D array
# - Shuffle: Shuffles the contents of a sequence

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
#If u want to replicate your results you need to set the seed
np.random.seed(1)
a=np.arange(2,10,3)
b=np.arange(100)
c=np.arange(100)
d=np.arange(10)
print(a)
#print(b)
# Out:
# [2 5 8]

# %%
#shuffle()

# %%
np.random.shuffle(b)
plt.plot(c,b)

# %%
np.random.shuffle(d)
print(d)
# Out:
# [0 7 1 3 8 2 9 5 4 6]

# %%
#random()
a=np.random.random(3)

# %%
print(a)
# Out:
# [0.90340192 0.1374747  0.13927635]

# %%
#rand()
a=np.random.rand(2,3)
print(a)
# Out:
# [[0.80739129 0.39767684 0.1653542 ]
#  [0.92750858 0.34776586 0.7508121 ]]

# %%
#randn()
a=np.random.randn(100,)
b=sorted(a)
plt.plot(b,a)
print(np.random.randn(2,3))
"""print(a)
print(b)"""
# Out:
# [[ 2.47441941 -0.33232485  0.77714652]
#  [ 0.09035118 -0.18659747  0.74325857]]
# 'print(a)\nprint(b)'

# %%
#randint()
a=np.random.randint(5,10,3)
print(a)
# Out:
# [7 9 8]

# %%
#choice()
element=np.random.choice([1,4,3,2,11,27])
print(element)
# Out:
# 11
